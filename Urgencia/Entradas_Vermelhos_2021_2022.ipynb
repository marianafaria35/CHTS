# %%
import pandas as pd
import numpy as np

# %%
adm=pd.read_excel(r'/Users/marianafaria/Desktop/ICDM_2010_2021 (1.2)/ICDM_2010_2021/Fonte/urg_altas_1.xlsx')

# %%
adm
# Out:
#         URG_EPISODIO  NUM_MECANOGRAFICO  COD_LOCAL DTA_ADMISSAO  \
# 0           22082630               6978          1   2022-05-25
# 1           22052092               9087          4   2022-04-04
# 2           21120090               6978          1   2021-09-13
# 3           22093655               8197          1   2022-06-13
# 4           22125631               5715          1   2022-08-10
# ...              ...                ...        ...          ...
# 348684      22167378               8240          1   2022-10-26
# 348685      22167382               9116          3   2022-10-26
# 348686      22167388                 20          3   2022-10-26
# 348687      22167434               8297          9   2022-10-26
# 348688      22167457               8297          9   2022-10-26
#
#         HORA_ADMISSAO  COD_CAUSA  COD_PROVENIENCIA  COD_UNIDADE_PROV  \
# 0                9246        5.0               5.0               NaN
# ...

# %%
adm.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 348689 entries, 0 to 348688
# Data columns (total 20 columns):
#  #   Column               Non-Null Count   Dtype
# ---  ------               --------------   -----
#  0   URG_EPISODIO         348689 non-null  int64
#  1   NUM_MECANOGRAFICO    348689 non-null  int64
#  2   COD_LOCAL            348689 non-null  int64
#  3   DTA_ADMISSAO         348689 non-null  object
#  4   HORA_ADMISSAO        348689 non-null  int64
#  5   COD_CAUSA            348672 non-null  float64
#  6   COD_PROVENIENCIA     348555 non-null  float64
#  7   COD_UNIDADE_PROV     38107 non-null   float64
#  8   COD_SUBSISTEMA_RESP  348689 non-null  int64
#  9   COD_PRIORIDADE       322830 non-null  float64
#  10  COD_SALA             347945 non-null  float64
#  11  COD_VIA_VERDE        7856 non-null    float64
#  12  DTA_TRIAGEM          322952 non-null  object
#  13  DTA_NASCIMENTO       348689 non-null  object
#  14  SEXO                 348689 non-null  int64
# ...

# %%
vermelhos=adm[(adm['COD_PRIORIDADE']==1)&(adm['COD_LOCAL']==1)]

# %%
vermelhos['URG_EPISODIO'].nunique()
# Out:
# 1227

# %%
vermelhos=vermelhos[['URG_EPISODIO','DTA_ADMISSAO']]

# %%
vermelhos["DTA_ADMISSAO"]=pd.to_datetime(vermelhos["DTA_ADMISSAO"])

# %%
vermelhos=vermelhos.groupby('DTA_ADMISSAO')['URG_EPISODIO'].count().reset_index()

# %%
vermelhos
# Out:
#     DTA_ADMISSAO  URG_EPISODIO
# 0     2021-01-01             4
# 1     2021-01-02             1
# 2     2021-01-03             1
# 3     2021-01-04             5
# 4     2021-01-06             5
# ..           ...           ...
# 561   2022-10-17             2
# 562   2022-10-18             2
# 563   2022-10-20             2
# 564   2022-10-24             3
# 565   2022-10-25             2
#
# [566 rows x 2 columns]

# %%
vermelhos=vermelhos.sort_values("DTA_ADMISSAO")

# %%
vermelhos["DTA_ADMISSAO"]=vermelhos["DTA_ADMISSAO"].astype(str)

# %%
vermelhos['Ano']=vermelhos['DTA_ADMISSAO'].apply(lambda x: x.split('-')[0])

# %%
vermelhos['Mes']=vermelhos['DTA_ADMISSAO'].apply(lambda x: x.split('-')[1])

# %%
vermelhos['Mes']=vermelhos['Mes'].astype(int)

# %%
vermelhos_adm=vermelhos[((vermelhos['Ano']=='2021')&(vermelhos['Mes']>8))|((vermelhos['Ano']=='2022')&(vermelhos['Mes']<9))]

# %%
vermelhos_adm
# Out:
#     DTA_ADMISSAO  URG_EPISODIO   Ano  Mes
# 204   2021-09-01             1  2021    9
# 205   2021-09-02             2  2021    9
# 206   2021-09-03             3  2021    9
# 207   2021-09-04             4  2021    9
# 208   2021-09-05             2  2021    9
# ..           ...           ...   ...  ...
# 518   2022-08-27             1  2022    8
# 519   2022-08-28             1  2022    8
# 520   2022-08-29             2  2022    8
# 521   2022-08-30             5  2022    8
# 522   2022-08-31             2  2022    8
#
# [319 rows x 4 columns]

# %%
vermelhos_adm["DTA_ADMISSAO"]=pd.to_datetime(vermelhos_adm["DTA_ADMISSAO"])
# Out:
# <ipython-input-18-b1abe400d16c>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   vermelhos_adm["DTA_ADMISSAO"]=pd.to_datetime(vermelhos_adm["DTA_ADMISSAO"])

# %%
vermelhos_adm=vermelhos_adm[['DTA_ADMISSAO','URG_EPISODIO']]

# %%
import plotly
import cufflinks as cf
from plotly.offline import download_plotlyjs, init_notebook_mode, plot, iplot
init_notebook_mode(connected=True)
cf.go_offline()
# Out:
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-2.4.2.min']
#             }
#         });
#         require(['plotly'], function(Plotly) {
#             window._Plotly = Plotly;
#         });
#         }
#         </script>
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-2.4.2.min']
#             }
#         });
# ...

# %%
vermelhos_adm.iplot(kind='scatter', x='DTA_ADMISSAO', y='URG_EPISODIO')
# Out:
# <div>                            <div id="6b48d289-d86a-4a9c-9fef-65a1322637fa" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};
# ...

# %%
ts=vermelhos_adm['URG_EPISODIO']
### Import Packages ###

import itertools
import statsmodels.api as sm

### Define Parameter Ranges to Test ###

# Note: higher numbers will result in code taking much longer to run
# Here we have it set to test p,d,q each = 0, 1 & 2

# Define the p, d and q parameters to take any value between 0 and 3 (exclusive)
p = d = q = range(0, 3)

# Generate all different combinations of p, q and q triplets
pdq = list(itertools.product(p, d, q))

# Generate all different combinations of seasonal p, q and q triplets
# Note: here we have 12 in the 's' position as we have monthly data
# You'll want to change this according to your time series' frequency
pdqs = [(x[0], x[1], x[2], 7) for x in list(itertools.product(p, d, q))]

### Run Grid Search ###

# Note: this code will take a while to run

# Define function
def sarimax_gridsearch(ts, pdq, pdqs, maxiter=50, freq='M'):
   # '''
    #Input: 
     #   ts : your time series data
      #  pdq : ARIMA combinations from above
       # pdqs : seasonal ARIMA combinations from above
       # maxiter : number of iterations, increase if your model isn't converging
       # frequency : default='M' for month. Change to suit your time series frequency
        #    e.g. 'D' for day, 'H' for hour, 'Y' for year. 
        
    #Return:
     #   Prints out top 5 parameter combinations
      #  Returns dataframe of parameter combinations ranked by BIC
    #'''

    # Run a grid search with pdq and seasonal pdq parameters and get the best BIC value
    ans = []
    for comb in pdq:
        for combs in pdqs:
            try:
                
                mod = sm.tsa.statespace.SARIMAX(ts,
                                                order=comb,
                                                seasonal_order=combs)

                output = mod.fit(maxiter=maxiter) 
                ans.append([comb, combs, output.bic])
                print('SARIMAX {} x {}7 : BIC Calculated ={}'.format(comb, combs, output.bic))
            except:
                continue
            
    # Find the parameters with minimal BIC value

    # Convert into dataframe
    ans_df = pd.DataFrame(ans, columns=['pdq', 'pdqs', 'bic'])

    # Sort and return top 5 combinations
    ans_df = ans_df.sort_values(by=['bic'],ascending=True)[0:5]
    
    return ans_df
    
### Apply function to your time series data ###

# Remember to change frequency to match your time series data
sarimax_gridsearch(ts, pdq, pdqs, freq='M')
# Out:
# /Users/marianafaria/opt/anaconda3/lib/python3.8/site-packages/statsmodels/tsa/base/tsa_model.py:578: ValueWarning:
#
# An unsupported index was provided and will be ignored when e.g. forecasting.
#
# /Users/marianafaria/opt/anaconda3/lib/python3.8/site-packages/statsmodels/tsa/base/tsa_model.py:578: ValueWarning:
#
# An unsupported index was provided and will be ignored when e.g. forecasting.
#
# /Users/marianafaria/opt/anaconda3/lib/python3.8/site-packages/statsmodels/tsa/base/tsa_model.py:578: ValueWarning:
#
# An unsupported index was provided and will be ignored when e.g. forecasting.
#
# /Users/marianafaria/opt/anaconda3/lib/python3.8/site-packages/statsmodels/tsa/base/tsa_model.py:578: ValueWarning:
#
# An unsupported index was provided and will be ignored when e.g. forecasting.
#
# /Users/marianafaria/opt/anaconda3/lib/python3.8/site-packages/statsmodels/tsa/base/tsa_model.py:578: ValueWarning:
#
# An unsupported index was provided and will be ignored when e.g. forecasting.
#
# ...

# %%
ts=vermelhos_adm['URG_EPISODIO']
### Import Packages ###

import itertools
import statsmodels.api as sm

### Define Parameter Ranges to Test ###

# Note: higher numbers will result in code taking much longer to run
# Here we have it set to test p,d,q each = 0, 1 & 2

# Define the p, d and q parameters to take any value between 0 and 3 (exclusive)
p = d = q = range(0, 3)

# Generate all different combinations of p, q and q triplets
pdq = list(itertools.product(p, d, q))

# Generate all different combinations of seasonal p, q and q triplets
# Note: here we have 12 in the 's' position as we have monthly data
# You'll want to change this according to your time series' frequency
pdqs = [(x[0], x[1], x[2], 30) for x in list(itertools.product(p, d, q))]

### Run Grid Search ###

# Note: this code will take a while to run

# Define function
def sarimax_gridsearch(ts, pdq, pdqs, maxiter=50, freq='M'):
   # '''
    #Input: 
     #   ts : your time series data
      #  pdq : ARIMA combinations from above
       # pdqs : seasonal ARIMA combinations from above
       # maxiter : number of iterations, increase if your model isn't converging
       # frequency : default='M' for month. Change to suit your time series frequency
        #    e.g. 'D' for day, 'H' for hour, 'Y' for year. 
        
    #Return:
     #   Prints out top 5 parameter combinations
      #  Returns dataframe of parameter combinations ranked by BIC
    #'''

    # Run a grid search with pdq and seasonal pdq parameters and get the best BIC value
    ans = []
    for comb in pdq:
        for combs in pdqs:
            try:
                
                mod = sm.tsa.statespace.SARIMAX(ts,
                                                order=comb,
                                                seasonal_order=combs)

                output = mod.fit(maxiter=maxiter) 
                ans.append([comb, combs, output.bic])
                print('SARIMAX {} x {}30 : BIC Calculated ={}'.format(comb, combs, output.bic))
            except:
                continue
            
    # Find the parameters with minimal BIC value

    # Convert into dataframe
    ans_df = pd.DataFrame(ans, columns=['pdq', 'pdqs', 'bic'])

    # Sort and return top 5 combinations
    ans_df = ans_df.sort_values(by=['bic'],ascending=True)[0:5]
    
    return ans_df
    
### Apply function to your time series data ###

# Remember to change frequency to match your time series data
sarimax_gridsearch(ts, pdq, pdqs, freq='M')
# Out:
# SARIMAX (0, 0, 0) x (0, 0, 0, 30)30 : BIC Calculated =1526.8988124859695
# /Users/marianafaria/opt/anaconda3/lib/python3.8/site-packages/statsmodels/tsa/base/tsa_model.py:578: ValueWarning:
#
# An unsupported index was provided and will be ignored when e.g. forecasting.
#
# /Users/marianafaria/opt/anaconda3/lib/python3.8/site-packages/statsmodels/tsa/base/tsa_model.py:578: ValueWarning:
#
# An unsupported index was provided and will be ignored when e.g. forecasting.
#
# /Users/marianafaria/opt/anaconda3/lib/python3.8/site-packages/statsmodels/tsa/base/tsa_model.py:578: ValueWarning:
#
# An unsupported index was provided and will be ignored when e.g. forecasting.
#
# /Users/marianafaria/opt/anaconda3/lib/python3.8/site-packages/statsmodels/tsa/base/tsa_model.py:578: ValueWarning:
#
# An unsupported index was provided and will be ignored when e.g. forecasting.
# SARIMAX (0, 0, 0) x (0, 0, 1, 30)30 : BIC Calculated =1419.8149830840523
# ...

# %%
vermelhos_Outubro=vermelhos[(vermelhos['Ano']=='2022')&((vermelhos['Mes']==9)|(vermelhos['Mes']==10))].reset_index()

# %%
vermelhos_Outubro=vermelhos_Outubro[['DTA_ADMISSAO','URG_EPISODIO']]

# %%
vermelhos_Outubro['DTA_ADMISSAO']=pd.to_datetime(vermelhos_Outubro['DTA_ADMISSAO'])

# %%
vermelhos_Outubro
# Out:
#    DTA_ADMISSAO  URG_EPISODIO
# 0    2022-09-01             2
# 1    2022-09-02             2
# 2    2022-09-03             3
# 3    2022-09-04             1
# 4    2022-09-05             1
# 5    2022-09-06             3
# 6    2022-09-07             2
# 7    2022-09-09             3
# 8    2022-09-10             2
# 9    2022-09-11             2
# 10   2022-09-12             2
# 11   2022-09-14             1
# 12   2022-09-15             3
# 13   2022-09-16             3
# 14   2022-09-17             1
# 15   2022-09-18             2
# 16   2022-09-19             1
# 17   2022-09-20             1
# 18   2022-09-21             1
# 19   2022-09-22             2
# 20   2022-09-23             2
# 21   2022-09-26             1
# 22   2022-09-28             1
# 23   2022-09-30             2
# 24   2022-10-01             1
# 25   2022-10-02             2
# 26   2022-10-03             1
# 27   2022-10-04             3
# 28   2022-10-05             1
# 29   2022-10-06             2
# ...

# %%
from statsmodels.tsa.statespace.sarimax import SARIMAX

treino=vermelhos_adm
teste=vermelhos_Outubro

array_pred=[]
array=[]
num_prev=[]
z=1
for x in range(len(teste)-15):
    y_treino=teste[0:z]
    h=pd.merge(treino,y_treino,on='DTA_ADMISSAO',how='outer').replace(np.nan,0)
    h['URG_EPISODIO']=h['URG_EPISODIO_x']+h['URG_EPISODIO_y']
    y_treino=h[['DTA_ADMISSAO','URG_EPISODIO']]
    best_model = SARIMAX(y_treino['URG_EPISODIO'],order=(2, 2, 2), seasonal_order=(1,1,1, 7)).fit()
    pred=best_model.forecast(steps=15)
    for y in pred.iloc:
        array_pred.append(y)
    t=teste[z:z+15]['URG_EPISODIO']
    for s in t.iloc:
        array.append(s)
    for x in range(15):
        num_prev.append(z)
    z=z+1
# Out:
# /Users/marianafaria/opt/anaconda3/lib/python3.8/site-packages/statsmodels/tsa/statespace/sarimax.py:978: UserWarning:
#
# Non-invertible starting MA parameters found. Using zeros as starting parameters.
#
# /Users/marianafaria/opt/anaconda3/lib/python3.8/site-packages/statsmodels/base/model.py:566: ConvergenceWarning:
#
# Maximum Likelihood optimization failed to converge. Check mle_retvals
#
# /Users/marianafaria/opt/anaconda3/lib/python3.8/site-packages/statsmodels/base/model.py:566: ConvergenceWarning:
#
# Maximum Likelihood optimization failed to converge. Check mle_retvals
#
# /Users/marianafaria/opt/anaconda3/lib/python3.8/site-packages/statsmodels/base/model.py:566: ConvergenceWarning:
#
# Maximum Likelihood optimization failed to converge. Check mle_retvals
#
# /Users/marianafaria/opt/anaconda3/lib/python3.8/site-packages/statsmodels/base/model.py:566: ConvergenceWarning:
#
# Maximum Likelihood optimization failed to converge. Check mle_retvals
#
# ...

# %%
treino=vermelhos_adm
teste=vermelhos_Outubro

array_pred_m=[]
array=[]
num_prev=[]
z=1
for x in range(len(teste)-15):
    y_treino=teste[0:z]
    h=pd.merge(treino,y_treino,on='DTA_ADMISSAO',how='outer').replace(np.nan,0)
    h['URG_EPISODIO']=h['URG_EPISODIO_x']+h['URG_EPISODIO_y']
    y_treino=h[['DTA_ADMISSAO','URG_EPISODIO']]
    best_model = SARIMAX(y_treino['URG_EPISODIO'],order=(0, 0, 0), seasonal_order=(0, 1, 1, 30)).fit()
    pred_m=best_model.forecast(steps=15)
    for y in pred_m.iloc:
        array_pred_m.append(y)
    t=teste[z:z+15]['URG_EPISODIO']
    for s in t.iloc:
        array.append(s)
    for x in range(15):
        num_prev.append(z)
    z=z+1

# %%
df = pd.DataFrame({'y':array, 'y_semana':array_pred, 'y_mes':array_pred_m, 'previsao':num_prev})

# %%
df[0:50]
# Out:
#     y  y_semana     y_mes  previsao
# 0   2  2.275335  2.600714         1
# 1   3  2.039376  2.399972         1
# 2   1  1.763358  2.099956         1
# 3   1  2.020683  2.500034         1
# 4   3  2.387781  1.800369         1
# 5   2  2.261859  2.200106         1
# 6   3  2.296869  2.099868         1
# 7   2  2.271797  2.199737         1
# 8   2  2.066075  2.499882         1
# 9   2  1.777669  2.600175         1
# 10  1  1.995409  2.364239         1
# 11  3  2.221368  2.727570         1
# 12  3  2.249722  2.181600         1
# 13  1  2.286716  2.272371         1
# 14  2  2.245637  2.090833         1
# 15  3  2.033790  2.399989         2
# 16  1  1.767123  2.099983         2
# 17  1  2.020740  2.500013         2
# 18  3  2.384077  1.800140         2
# 19  2  2.261439  2.200040         2
# 20  3  2.296264  2.099950         2
# 21  2  2.250184  2.199900         2
# 22  2  2.064110  2.499955         2
# 23  2  1.776073  2.600066         2
# 24  1  1.993181  2.363866         2
# ...

# %%
med=df['y'].mean()
z=0
for x in df.iloc:
    y=abs(x['y']-x['y_mes'])
    z=z+y
erro_m=z/len(df)

# %%
med=df['y'].mean()
z=0
for x in df.iloc:
    y=abs(x['y']-x['y_semana'])
    z=z+y
erro_s=z/len(df)

# %%
erro_s
# Out:
# 0.7414843239429991

# %%
erro_m
# Out:
# 0.8639606033808267

# %%
erro_m/med*100
# Out:
# 49.84388096427846

# %%
erro_s/med*100
# Out:
# 42.77794176594226

# %%
med
# Out:
# 1.7333333333333334
