# %%
import pandas as pd
import numpy as np

# %%
adm=pd.read_excel(r'/Users/marianafaria/Desktop/ICDM_2010_2021 (1.2)/ICDM_2010_2021/Fonte/urg_altas_1.xlsx')

# %%
adm
# Out:
#         URG_EPISODIO  NUM_MECANOGRAFICO  COD_LOCAL DTA_ADMISSAO  \
# 0           22082630               6978          1   2022-05-25
# 1           22052092               9087          4   2022-04-04
# 2           21120090               6978          1   2021-09-13
# 3           22093655               8197          1   2022-06-13
# 4           22125631               5715          1   2022-08-10
# ...              ...                ...        ...          ...
# 348684      22167378               8240          1   2022-10-26
# 348685      22167382               9116          3   2022-10-26
# 348686      22167388                 20          3   2022-10-26
# 348687      22167434               8297          9   2022-10-26
# 348688      22167457               8297          9   2022-10-26
#
#         HORA_ADMISSAO  COD_CAUSA  COD_PROVENIENCIA  COD_UNIDADE_PROV  \
# 0                9246        5.0               5.0               NaN
# ...

# %%
adm.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 348689 entries, 0 to 348688
# Data columns (total 20 columns):
#  #   Column               Non-Null Count   Dtype
# ---  ------               --------------   -----
#  0   URG_EPISODIO         348689 non-null  int64
#  1   NUM_MECANOGRAFICO    348689 non-null  int64
#  2   COD_LOCAL            348689 non-null  int64
#  3   DTA_ADMISSAO         348689 non-null  object
#  4   HORA_ADMISSAO        348689 non-null  int64
#  5   COD_CAUSA            348672 non-null  float64
#  6   COD_PROVENIENCIA     348555 non-null  float64
#  7   COD_UNIDADE_PROV     38107 non-null   float64
#  8   COD_SUBSISTEMA_RESP  348689 non-null  int64
#  9   COD_PRIORIDADE       322830 non-null  float64
#  10  COD_SALA             347945 non-null  float64
#  11  COD_VIA_VERDE        7856 non-null    float64
#  12  DTA_TRIAGEM          322952 non-null  object
#  13  DTA_NASCIMENTO       348689 non-null  object
#  14  SEXO                 348689 non-null  int64
# ...

# %%
verdes=adm[(adm['COD_PRIORIDADE']==4)&(adm['COD_LOCAL']==1)]

# %%
verdes['URG_EPISODIO'].nunique()
# Out:
# 53017

# %%
verdes=verdes[['URG_EPISODIO','DTA_ADMISSAO']]

# %%
verdes["DTA_ADMISSAO"]=pd.to_datetime(verdes["DTA_ADMISSAO"])

# %%
verdes=verdes.groupby('DTA_ADMISSAO')['URG_EPISODIO'].count().reset_index()

# %%
verdes
# Out:
#     DTA_ADMISSAO  URG_EPISODIO
# 0     2021-01-01            51
# 1     2021-01-02            59
# 2     2021-01-03            55
# 3     2021-01-04            82
# 4     2021-01-05            61
# ..           ...           ...
# 659   2022-10-22            67
# 660   2022-10-23            71
# 661   2022-10-24           109
# 662   2022-10-25            84
# 663   2022-10-26            35
#
# [664 rows x 2 columns]

# %%
verdes=verdes.sort_values("DTA_ADMISSAO")

# %%
verdes["DTA_ADMISSAO"]=verdes["DTA_ADMISSAO"].astype(str)

# %%
verdes['Ano']=verdes['DTA_ADMISSAO'].apply(lambda x: x.split('-')[0])

# %%
verdes['Mes']=verdes['DTA_ADMISSAO'].apply(lambda x: x.split('-')[1])

# %%
verdes['Mes']=verdes['Mes'].astype(int)

# %%
verdes
# Out:
#     DTA_ADMISSAO  URG_EPISODIO   Ano  Mes
# 0     2021-01-01            51  2021    1
# 1     2021-01-02            59  2021    1
# 2     2021-01-03            55  2021    1
# 3     2021-01-04            82  2021    1
# 4     2021-01-05            61  2021    1
# ..           ...           ...   ...  ...
# 659   2022-10-22            67  2022   10
# 660   2022-10-23            71  2022   10
# 661   2022-10-24           109  2022   10
# 662   2022-10-25            84  2022   10
# 663   2022-10-26            35  2022   10
#
# [664 rows x 4 columns]

# %%
verdes_adm=verdes[((verdes['Ano']=='2021')&(verdes['Mes']>8))|((verdes['Ano']=='2022')&(verdes['Mes']<9))]

# %%
verdes_adm
# Out:
#     DTA_ADMISSAO  URG_EPISODIO   Ano  Mes
# 243   2021-09-01            95  2021    9
# 244   2021-09-02            79  2021    9
# 245   2021-09-03            83  2021    9
# 246   2021-09-04            67  2021    9
# 247   2021-09-05            73  2021    9
# ..           ...           ...   ...  ...
# 603   2022-08-27            76  2022    8
# 604   2022-08-28            72  2022    8
# 605   2022-08-29           103  2022    8
# 606   2022-08-30            76  2022    8
# 607   2022-08-31            80  2022    8
#
# [365 rows x 4 columns]

# %%
verdes_adm["DTA_ADMISSAO"]=pd.to_datetime(verdes_adm["DTA_ADMISSAO"])
# Out:
# <ipython-input-19-4e4c111037a3>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   verdes_adm["DTA_ADMISSAO"]=pd.to_datetime(verdes_adm["DTA_ADMISSAO"])

# %%
verdes_adm=verdes_adm[['DTA_ADMISSAO','URG_EPISODIO']]

# %%
import plotly
import cufflinks as cf
from plotly.offline import download_plotlyjs, init_notebook_mode, plot, iplot
init_notebook_mode(connected=True)
cf.go_offline()
# Out:
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-2.4.2.min']
#             }
#         });
#         require(['plotly'], function(Plotly) {
#             window._Plotly = Plotly;
#         });
#         }
#         </script>
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-2.4.2.min']
#             }
#         });
# ...

# %%
verdes_adm.iplot(kind='scatter', x='DTA_ADMISSAO', y='URG_EPISODIO')
# Out:
# <div>                            <div id="ab36442d-62ed-41c5-87b7-0e51c923675b" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};
# ...

# %%
ts=verdes_adm['URG_EPISODIO']
### Import Packages ###

import itertools
import statsmodels.api as sm

### Define Parameter Ranges to Test ###

# Note: higher numbers will result in code taking much longer to run
# Here we have it set to test p,d,q each = 0, 1 & 2

# Define the p, d and q parameters to take any value between 0 and 3 (exclusive)
p = d = q = range(0, 3)

# Generate all different combinations of p, q and q triplets
pdq = list(itertools.product(p, d, q))

# Generate all different combinations of seasonal p, q and q triplets
# Note: here we have 12 in the 's' position as we have monthly data
# You'll want to change this according to your time series' frequency
pdqs = [(x[0], x[1], x[2], 7) for x in list(itertools.product(p, d, q))]

### Run Grid Search ###

# Note: this code will take a while to run

# Define function
def sarimax_gridsearch(ts, pdq, pdqs, maxiter=50, freq='M'):
   # '''
    #Input: 
     #   ts : your time series data
      #  pdq : ARIMA combinations from above
       # pdqs : seasonal ARIMA combinations from above
       # maxiter : number of iterations, increase if your model isn't converging
       # frequency : default='M' for month. Change to suit your time series frequency
        #    e.g. 'D' for day, 'H' for hour, 'Y' for year. 
        
    #Return:
     #   Prints out top 5 parameter combinations
      #  Returns dataframe of parameter combinations ranked by BIC
    #'''

    # Run a grid search with pdq and seasonal pdq parameters and get the best BIC value
    ans = []
    for comb in pdq:
        for combs in pdqs:
            try:
                
                mod = sm.tsa.statespace.SARIMAX(ts,
                                                order=comb,
                                                seasonal_order=combs)

                output = mod.fit(maxiter=maxiter) 
                ans.append([comb, combs, output.bic])
                print('SARIMAX {} x {}7 : BIC Calculated ={}'.format(comb, combs, output.bic))
            except:
                continue
            
    # Find the parameters with minimal BIC value

    # Convert into dataframe
    ans_df = pd.DataFrame(ans, columns=['pdq', 'pdqs', 'bic'])

    # Sort and return top 5 combinations
    ans_df = ans_df.sort_values(by=['bic'],ascending=True)[0:5]
    
    return ans_df
    
### Apply function to your time series data ###

# Remember to change frequency to match your time series data
sarimax_gridsearch(ts, pdq, pdqs, freq='M')
# Out:
# /Users/marianafaria/opt/anaconda3/lib/python3.8/site-packages/statsmodels/tsa/base/tsa_model.py:578: ValueWarning:
#
# An unsupported index was provided and will be ignored when e.g. forecasting.
#
# /Users/marianafaria/opt/anaconda3/lib/python3.8/site-packages/statsmodels/tsa/base/tsa_model.py:578: ValueWarning:
#
# An unsupported index was provided and will be ignored when e.g. forecasting.
#
# /Users/marianafaria/opt/anaconda3/lib/python3.8/site-packages/statsmodels/tsa/base/tsa_model.py:578: ValueWarning:
#
# An unsupported index was provided and will be ignored when e.g. forecasting.
#
# /Users/marianafaria/opt/anaconda3/lib/python3.8/site-packages/statsmodels/tsa/base/tsa_model.py:578: ValueWarning:
#
# An unsupported index was provided and will be ignored when e.g. forecasting.
# SARIMAX (0, 0, 0) x (0, 0, 0, 7)7 : BIC Calculated =4285.844583012392
# SARIMAX (0, 0, 0) x (0, 0, 1, 7)7 : BIC Calculated =3944.2735506840877
# ...

# %%
ts=verdes_adm['URG_EPISODIO']
### Import Packages ###

import itertools
import statsmodels.api as sm

### Define Parameter Ranges to Test ###

# Note: higher numbers will result in code taking much longer to run
# Here we have it set to test p,d,q each = 0, 1 & 2

# Define the p, d and q parameters to take any value between 0 and 3 (exclusive)
p = d = q = range(0, 3)

# Generate all different combinations of p, q and q triplets
pdq = list(itertools.product(p, d, q))

# Generate all different combinations of seasonal p, q and q triplets
# Note: here we have 12 in the 's' position as we have monthly data
# You'll want to change this according to your time series' frequency
pdqs = [(x[0], x[1], x[2], 30) for x in list(itertools.product(p, d, q))]

### Run Grid Search ###

# Note: this code will take a while to run

# Define function
def sarimax_gridsearch(ts, pdq, pdqs, maxiter=50, freq='M'):
   # '''
    #Input: 
     #   ts : your time series data
      #  pdq : ARIMA combinations from above
       # pdqs : seasonal ARIMA combinations from above
       # maxiter : number of iterations, increase if your model isn't converging
       # frequency : default='M' for month. Change to suit your time series frequency
        #    e.g. 'D' for day, 'H' for hour, 'Y' for year. 
        
    #Return:
     #   Prints out top 5 parameter combinations
      #  Returns dataframe of parameter combinations ranked by BIC
    #'''

    # Run a grid search with pdq and seasonal pdq parameters and get the best BIC value
    ans = []
    for comb in pdq:
        for combs in pdqs:
            try:
                
                mod = sm.tsa.statespace.SARIMAX(ts,
                                                order=comb,
                                                seasonal_order=combs)

                output = mod.fit(maxiter=maxiter) 
                ans.append([comb, combs, output.bic])
                print('SARIMAX {} x {}30 : BIC Calculated ={}'.format(comb, combs, output.bic))
            except:
                continue
            
    # Find the parameters with minimal BIC value

    # Convert into dataframe
    ans_df = pd.DataFrame(ans, columns=['pdq', 'pdqs', 'bic'])

    # Sort and return top 5 combinations
    ans_df = ans_df.sort_values(by=['bic'],ascending=True)[0:5]
    
    return ans_df
    
### Apply function to your time series data ###

# Remember to change frequency to match your time series data
sarimax_gridsearch(ts, pdq, pdqs, freq='M')
# Out:
# SARIMAX (0, 0, 0) x (0, 0, 0, 30)30 : BIC Calculated =4285.844583012392
# /Users/marianafaria/opt/anaconda3/lib/python3.8/site-packages/statsmodels/tsa/base/tsa_model.py:578: ValueWarning:
#
# An unsupported index was provided and will be ignored when e.g. forecasting.
#
# /Users/marianafaria/opt/anaconda3/lib/python3.8/site-packages/statsmodels/tsa/base/tsa_model.py:578: ValueWarning:
#
# An unsupported index was provided and will be ignored when e.g. forecasting.
#
# /Users/marianafaria/opt/anaconda3/lib/python3.8/site-packages/statsmodels/tsa/base/tsa_model.py:578: ValueWarning:
#
# An unsupported index was provided and will be ignored when e.g. forecasting.
#
# /Users/marianafaria/opt/anaconda3/lib/python3.8/site-packages/statsmodels/tsa/base/tsa_model.py:578: ValueWarning:
#
# An unsupported index was provided and will be ignored when e.g. forecasting.
# SARIMAX (0, 0, 0) x (0, 0, 1, 30)30 : BIC Calculated =4014.997968644809
# ...

# %%
verdes_Outubro=verdes[(verdes['Ano']=='2022')&((verdes['Mes']==9)|(verdes['Mes']==10))].reset_index()

# %%
verdes_Outubro=verdes_Outubro[['DTA_ADMISSAO','URG_EPISODIO']]

# %%
verdes_Outubro['DTA_ADMISSAO']=pd.to_datetime(verdes_Outubro['DTA_ADMISSAO'])

# %%
verdes_Outubro
# Out:
#    DTA_ADMISSAO  URG_EPISODIO
# 0    2022-09-01            76
# 1    2022-09-02            73
# 2    2022-09-03            69
# 3    2022-09-04            49
# 4    2022-09-05           107
# 5    2022-09-06            75
# 6    2022-09-07            89
# 7    2022-09-08            95
# 8    2022-09-09            52
# 9    2022-09-10            60
# 10   2022-09-11            50
# 11   2022-09-12            78
# 12   2022-09-13            79
# 13   2022-09-14            64
# 14   2022-09-15            61
# 15   2022-09-16            65
# 16   2022-09-17            77
# 17   2022-09-18            95
# 18   2022-09-19            84
# 19   2022-09-20            94
# 20   2022-09-21           107
# 21   2022-09-22            98
# 22   2022-09-23            74
# 23   2022-09-24            70
# 24   2022-09-25            83
# 25   2022-09-26           125
# 26   2022-09-27            77
# 27   2022-09-28            75
# 28   2022-09-29            90
# 29   2022-09-30            94
# ...

# %%
from statsmodels.tsa.statespace.sarimax import SARIMAX

treino=verdes_adm
teste=verdes_Outubro

array_pred=[]
array=[]
num_prev=[]
dia=[]
z=1

for x in range(len(teste)-15):
    y_treino=teste[0:z]
    h=pd.merge(treino,y_treino,on='DTA_ADMISSAO',how='outer').replace(np.nan,0)
    h['URG_EPISODIO']=h['URG_EPISODIO_x']+h['URG_EPISODIO_y']
    y_treino=h[['DTA_ADMISSAO','URG_EPISODIO']]
    best_model = SARIMAX(y_treino['URG_EPISODIO'],order=(1, 0, 1), seasonal_order=(0, 1, 1, 7)).fit()
    pred=best_model.forecast(steps=15)
    for y in pred.iloc:
        array_pred.append(y)
    t=teste[z:z+15]['URG_EPISODIO']
    for s in t.iloc:
        array.append(s)
    for x in range(15):
        num_prev.append(z)
    t=0
    for x in range(15):
        t=t+1
        dia.append(t)
    z=z+1

# %%
treino=verdes_adm
teste=verdes_Outubro

array_pred_m=[]
array=[]
num_prev=[]
z=1

for x in range(len(teste)-15):
    y_treino=teste[0:z]
    h=pd.merge(treino,y_treino,on='DTA_ADMISSAO',how='outer').replace(np.nan,0)
    h['URG_EPISODIO']=h['URG_EPISODIO_x']+h['URG_EPISODIO_y']
    y_treino=h[['DTA_ADMISSAO','URG_EPISODIO']]
    best_model = SARIMAX(y_treino['URG_EPISODIO'],order=(1, 0, 0), seasonal_order=(0, 2, 2, 30)).fit()
    pred_m=best_model.forecast(steps=15)
    for y in pred_m.iloc:
        array_pred_m.append(y)
    t=teste[z:z+15]['URG_EPISODIO']
    for s in t.iloc:
        array.append(s)
    for x in range(15):
        num_prev.append(z)
    z=z+1

# %%
df = pd.DataFrame({'y':array, 'y_semana':array_pred, 'y_mes':array_pred_m, 'previsao':num_prev, 'dia':dia})

# %%
df
# Out:
#        y    y_semana      y_mes  previsao  dia   erro_mes  erro_semana
# 0     73   75.629216  84.996430         1    1  11.996430     2.629216
# 1     69   67.883013  78.519449         1    2   9.519449     1.116987
# 2     49   69.056299  77.770110         1    3  28.770110    20.056299
# 3    107  101.559610  64.792760         1    4  42.207240     5.440390
# 4     75   83.165536  82.446555         1    5   7.446555     8.165536
# ..   ...         ...        ...       ...  ...        ...          ...
# 610   67   70.447799  76.216045        41   11   9.216045     3.447799
# 611   71   71.950817  80.416245        41   12   9.416245     0.950817
# 612  109  102.969359  66.295030        41   13  42.704970     6.030641
# 613   84   84.659359  74.061887        41   14   9.938113     0.659359
# 614   35   87.834422  76.626344        41   15  41.626344    52.834422
#
# [615 rows x 7 columns]

# %%
med=df['y'].mean()
z=0
erro_max_mes=0
a=[]
for x in df.iloc:
    y=abs(x['y']-x['y_mes'])
    a.append(y)
    z=z+y
erro_m=z/len(df)

df['erro_mes']=a

# %%
med=df['y'].mean()
z=0
erro_max_semana=0
a=[]
for x in df.iloc:
    y=abs(x['y']-x['y_semana'])
    a.append(y)
    z=z+y
erro_s=z/len(df)

df['erro_semana']=a

# %%
df.sort_values('erro_semana', ascending=False)[:15]
# Out:
#        y   y_semana      y_mes  previsao  dia   erro_mes  erro_semana
# 614   35  87.834422  76.626344        41   15  41.626344    52.834422
# 552   43  86.249363  81.581672        37   13  38.581672    43.249363
# 580   43  85.592041  81.580681        39   11  38.580681    42.592041
# 538   43  85.551950  81.581537        36   14  38.581537    42.551950
# 566   43  84.796757  81.580473        38   12  38.580473    41.796757
# 594   43  84.312053  81.580275        40   10  38.580275    41.312053
# 524   43  83.890528  81.581114        35   15  38.581114    40.890528
# 608   43  83.125107  81.576684        41    9  38.576684    40.125107
# 412  117  82.525368  80.048762        28    8  36.951238    34.474632
# 226   95  60.603474  73.397373        16    2  21.602627    34.396526
# 212   95  60.840955  74.461050        15    3  20.538950    34.159045
# 314  117  82.875426  80.000866        21   15  36.999134    34.124574
# ...

# %%
df[df['previsao']==41]
# Out:
#        y    y_semana      y_mes  previsao  dia   erro_mes  erro_semana
# 600   84   87.435070  77.959510        41    1   6.040490     3.435070
# 601   69   82.875678  87.120823        41    2  18.120823    13.875678
# 602   91   78.240487  74.679481        41    3  16.320519    12.759513
# 603   60   70.254572  95.957807        41    4  35.957807    10.254572
# 604  103   71.780746  93.927375        41    5   9.072625    31.219254
# 605  126  102.819670  74.582066        41    6  51.417934    23.180330
# 606   83   84.527609  78.173096        41    7   4.826904     1.527609
# 607   67   87.718461  70.072197        41    8   3.072197    20.718461
# 608   43   83.125107  81.576684        41    9  38.576684    40.125107
# 609   64   78.460023  97.379142        41   10  33.379142    14.460023
# 610   67   70.447799  76.216045        41   11   9.216045     3.447799
# 611   71   71.950817  80.416245        41   12   9.416245     0.950817
# ...

# %%
df[df['erro_semana']>2*(erro_s)]
# Out:
#        y   y_semana      y_mes  previsao  dia   erro_mes  erro_semana
# 170   95  63.733061  74.774182        12    6  20.225818    31.266939
# 184   95  64.220966  74.770250        13    5  20.229750    30.779034
# 198   95  62.619706  74.754052        14    4  20.245948    32.380294
# 212   95  60.840955  74.461050        15    3  20.538950    34.159045
# 226   95  60.603474  73.397373        16    2  21.602627    34.396526
# 240   95  63.759800  75.046639        17    1  19.953361    31.240200
# 314  117  82.875426  80.000866        21   15  36.999134    34.124574
# 328  117  83.535447  80.019263        22   14  36.980737    33.464553
# 342  117  83.198820  80.030163        23   13  36.969837    33.801180
# 356  117  83.050036  80.029379        24   12  36.970621    33.949964
# 370  117  83.566351  80.028770        25   11  36.971230    33.433649
# 384  117  84.662954  80.066332        26   10  36.933668    32.337046
# ...

# %%
len(df[df['erro_semana']>2*(erro_s)])
# Out:
# 31

# %%
len(df[df['erro_semana']>(erro_s)])
# Out:
# 302

# %%
erro_s
# Out:
# 14.921927224630213

# %%
erro_m
# Out:
# 18.312673599826287

# %%
erro_m/med*100
# Out:
# 21.852832458026597

# %%
erro_s/med*100
# Out:
# 17.806595733448944

# %%
med
# Out:
# 83.8

# %%
verdes_adm
# Out:
#     DTA_ADMISSAO  URG_EPISODIO
# 243   2021-09-01            95
# 244   2021-09-02            79
# 245   2021-09-03            83
# 246   2021-09-04            67
# 247   2021-09-05            73
# ..           ...           ...
# 603   2022-08-27            76
# 604   2022-08-28            72
# 605   2022-08-29           103
# 606   2022-08-30            76
# 607   2022-08-31            80
#
# [365 rows x 2 columns]

# %%
data_prop=verdes_adm

# %%
data_prop['ds']=data_prop['DTA_ADMISSAO']
data_prop['y']=data_prop['URG_EPISODIO']
data_prop=data_prop[['ds','y']]
# Out:
# <ipython-input-27-31d579b17db6>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data_prop['ds']=data_prop['DTA_ADMISSAO']

# %%
data_prop
# Out:
#             ds    y
# 243 2021-09-01   95
# 244 2021-09-02   79
# 245 2021-09-03   83
# 246 2021-09-04   67
# 247 2021-09-05   73
# ..         ...  ...
# 603 2022-08-27   76
# 604 2022-08-28   72
# 605 2022-08-29  103
# 606 2022-08-30   76
# 607 2022-08-31   80
#
# [365 rows x 2 columns]

# %%
verdes['DTA_ADMISSAO']=pd.to_datetime(verdes['DTA_ADMISSAO'])

# %%
data_teste=verdes_Outubro.rename(columns={"DTA_ADMISSAO": "ds", "URG_EPISODIO": "y"})

# %%
data_teste
# Out:
#            ds    y
# 0  2022-09-01   76
# 1  2022-09-02   73
# 2  2022-09-03   69
# 3  2022-09-04   49
# 4  2022-09-05  107
# 5  2022-09-06   75
# 6  2022-09-07   89
# 7  2022-09-08   95
# 8  2022-09-09   52
# 9  2022-09-10   60
# 10 2022-09-11   50
# 11 2022-09-12   78
# 12 2022-09-13   79
# 13 2022-09-14   64
# 14 2022-09-15   61
# 15 2022-09-16   65
# 16 2022-09-17   77
# 17 2022-09-18   95
# 18 2022-09-19   84
# 19 2022-09-20   94
# 20 2022-09-21  107
# 21 2022-09-22   98
# 22 2022-09-23   74
# 23 2022-09-24   70
# 24 2022-09-25   83
# 25 2022-09-26  125
# 26 2022-09-27   77
# 27 2022-09-28   75
# 28 2022-09-29   90
# 29 2022-09-30   94
# 30 2022-10-01   86
# 31 2022-10-02   92
# 32 2022-10-03   97
# 33 2022-10-04   93
# 34 2022-10-05  103
# 35 2022-10-06  117
# 36 2022-10-07  103
# 37 2022-10-08   55
# 38 2022-10-09   90
# 39 2022-10-10   91
# 40 2022-10-11   71
# 41 2022-10-12   84
# 42 2022-10-13   69
# 43 2022-10-14   91
# 44 2022-10-15   60
# 45 2022-10-16  103
# ...

# %% [markdown]
# # prophet

# %%
from prophet import Prophet

m = Prophet()
predict = m.fit(data_prop)
future = m.make_future_dataframe(periods=15)
t=m.predict(future)
# Out:
# INFO:prophet:Disabling yearly seasonality. Run prophet with yearly_seasonality=True to override this.
# INFO:prophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.

# %%
t=t[['ds','yhat','yhat_lower','yhat_upper']]

# %%
prev = pd.merge(t, verdes, left_on='ds', right_on='DTA_ADMISSAO').drop(['DTA_ADMISSAO','Ano','Mes'], axis=1)

# %%
med=prev['URG_EPISODIO'].mean()
z=0

for x in prev.iloc:
    y=abs(x['yhat']-x['URG_EPISODIO'])
    z=z+y
erro_s=z/len(prev)

# %%
erro_s
# Out:
# 12.638238639751348

# %%
erro_s/med*100
# Out:
# 15.321031975708262

# %%
from prophet import Prophet

treino=data_prop
teste=data_teste

array_pred_m=[]
array=[]
num_prev=[]
z=1
dia=[]
maxi=[]
mini=[]

for x in range(len(teste)-15):
    y_treino=teste[0:z]
    h=pd.merge(treino,y_treino,on='ds',how='outer').replace(np.nan,0)
    h['y']=h['y_x']+h['y_y']
    y_treino=h[['ds','y']]
    m = Prophet()
    best_model = m.fit(y_treino)
    future=m.make_future_dataframe(periods=15)
    pred_m=m.predict(future)
    
    for y in pred_m[-15:].iloc:
        array_pred_m.append(y['yhat'])
        maxi.append(y['yhat_upper'])
        mini.append(y['yhat_lower'])
    t=teste[z:z+15]['y']
    
    for s in t.iloc:
        array.append(s)
    
    for x in range(15):
        num_prev.append(z)
    
    t=0
    for x in range(15):
        t=t+1
        dia.append(t)
    z=z+1
# Out:
# INFO:prophet:Disabling yearly seasonality. Run prophet with yearly_seasonality=True to override this.
# INFO:prophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# INFO:prophet:Disabling yearly seasonality. Run prophet with yearly_seasonality=True to override this.
# INFO:prophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# INFO:prophet:Disabling yearly seasonality. Run prophet with yearly_seasonality=True to override this.
# INFO:prophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# INFO:prophet:Disabling yearly seasonality. Run prophet with yearly_seasonality=True to override this.
# INFO:prophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# INFO:prophet:Disabling yearly seasonality. Run prophet with yearly_seasonality=True to override this.
# ...

# %%
previsao = pd.DataFrame({'y':array, 'y_previsto':array_pred_m, 'y_max':maxi, 'y_min':mini, 'dia':dia, 'previsao':num_prev})

# %%
previsao
# Out:
#        y  y_previsto       y_max      y_min  dia  previsao
# 0     73   74.920946   95.769600  54.551551    1         1
# 1     69   66.802013   87.839830  47.507878    2         1
# 2     49   67.643343   87.334298  47.555194    3         1
# 3    107   99.845667  118.751535  79.852722    4         1
# 4     75   81.189850  101.273911  60.963773    5         1
# ..   ...         ...         ...        ...  ...       ...
# 610   67   67.573668   87.207372  48.188838   11        41
# 611   71   69.057880   89.462255  48.074182   12        41
# 612  109  100.071093  120.114780  78.336713   13        41
# 613   84   81.737062  102.030509  62.002252   14        41
# 614   35   84.826302  104.077004  63.577358   15        41
#
# [615 rows x 6 columns]

# %%
previsao[(previsao['y']>previsao['y_max'])|(previsao['y']<previsao['y_min'])]
# Out:
#        y  y_previsto       y_max      y_min  dia  previsao
# 7     52   74.752572   97.044657  53.116822    8         1
# 10    78   99.677293  120.570914  78.825792   11         1
# 21    52   74.657000   94.172088  53.898102    7         2
# 24    78   99.624875  119.000705  78.665651   10         2
# 35    52   74.469767   95.192132  53.611528    6         3
# ..   ...         ...         ...        ...  ...       ...
# 594   43   80.419920  100.112490  59.831094   10        40
# 604  103   69.154375   90.137026  47.877191    5        41
# 605  126  100.167588  119.675772  80.284452    6        41
# 608   43   80.301156  100.257319  59.739886    9        41
# 614   35   84.826302  105.016099  63.244902   15        41
#
# [185 rows x 6 columns]

# %%
med=previsao['y'].mean()
z=0

for x in previsao.iloc:
    y=abs(x['y_previsto']-x['y'])
    z=z+y
erro=z/len(previsao)

# %%
erro
# Out:
# 15.262525518618578

# %%
erro/med*100
# Out:
# 18.213037611716683

# %%
med
# Out:
# 83.8

# %%
from prophet import Prophet

treino=data_prop
teste=data_teste

array_pred_m=[]
array=[]
num_prev=[]
z=1
dia=[]
maxi=[]
mini=[]

for x in range(len(teste)-7):
    y_treino=teste[0:z]
    h=pd.merge(treino,y_treino,on='ds',how='outer').replace(np.nan,0)
    h['y']=h['y_x']+h['y_y']
    y_treino=h[['ds','y']]
    m = Prophet()
    best_model = m.fit(y_treino)
    future=m.make_future_dataframe(periods=7)
    pred_m=m.predict(future)
    
    for y in pred_m[-7:].iloc:
        array_pred_m.append(y['yhat'])
        maxi.append(y['yhat_upper'])
        mini.append(y['yhat_lower'])
    t=teste[z:z+7]['y']
    
    for s in t.iloc:
        array.append(s)
    
    for x in range(7):
        num_prev.append(z)
    
    t=0
    for x in range(7):
        t=t+1
        dia.append(t)
    z=z+1
# Out:
# INFO:prophet:Disabling yearly seasonality. Run prophet with yearly_seasonality=True to override this.
# INFO:prophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# INFO:prophet:Disabling yearly seasonality. Run prophet with yearly_seasonality=True to override this.
# INFO:prophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# INFO:prophet:Disabling yearly seasonality. Run prophet with yearly_seasonality=True to override this.
# INFO:prophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# INFO:prophet:Disabling yearly seasonality. Run prophet with yearly_seasonality=True to override this.
# INFO:prophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# INFO:prophet:Disabling yearly seasonality. Run prophet with yearly_seasonality=True to override this.
# ...

# %%
previsao = pd.DataFrame({'y':array, 'y_previsto':array_pred_m, 'y_max':maxi, 'y_min':mini, 'dia':dia, 'previsao':num_prev})

# %%
previsao[(previsao['y']>previsao['y_max'])|(previsao['y']<previsao['y_min'])]
# Out:
#       y  y_previsto       y_max      y_min  dia  previsao
# 13   52   74.657000   96.335470  54.882135    7         2
# 19   52   74.469767   94.082744  55.434418    6         3
# 25   52   73.443821   92.819519  52.927627    5         4
# 31   52   73.800239   93.863064  54.028629    4         5
# 34   78   98.869545  119.033655  79.113078    7         5
# ..   ..         ...         ...        ...  ...       ...
# 318  43   80.261317  101.468258  60.394941    4        46
# 324  43   80.557962  101.370629  60.614532    3        47
# 330  43   80.515079  101.415537  59.163018    2        48
# 336  43   80.336533  101.038648  60.826673    1        49
# 342  35   84.741399  106.233990  62.690296    7        49
#
# [98 rows x 6 columns]

# %%
previsao[(previsao['y']>previsao['y_max'])]
# Out:
#        y  y_previsto       y_max      y_min  dia  previsao
# 76    95   64.995403   84.699705  42.921069    7        11
# 82    95   65.112896   87.308879  44.739205    6        12
# 88    95   65.077659   88.020343  45.606057    5        13
# 94    95   64.155383   84.860610  44.727809    4        14
# 97   107   80.819822  101.562993  59.903835    7        14
# ..   ...         ...         ...        ...  ...       ...
# 302  103   69.194801   89.905804  48.679934    2        44
# 303  126  100.142496  120.191685  78.604236    3        44
# 308  103   69.096684   88.963460  47.905356    1        45
# 309  126  100.097707  121.755318  79.875190    2        45
# 315  126  100.311634  119.442169  79.815140    1        46
#
# [75 rows x 6 columns]

# %%
previsao[(previsao['y']<previsao['y_min'])]
# Out:
#       y  y_previsto       y_max      y_min  dia  previsao
# 13   52   74.657000   96.335470  54.882135    7         2
# 19   52   74.469767   94.082744  55.434418    6         3
# 25   52   73.443821   92.819519  52.927627    5         4
# 31   52   73.800239   93.863064  54.028629    4         5
# 34   78   98.869545  119.033655  79.113078    7         5
# 37   52   73.936516   93.738921  54.326568    3         6
# 43   52   74.735043   95.809784  53.802650    2         7
# 46   78   99.867116  119.623160  79.272637    5         7
# 48   64   83.931601  104.507219  64.643464    7         7
# 49   52   74.544047   94.367652  53.869323    1         8
# 52   78   99.702882  120.425199  80.321417    4         8
# 54   64   83.737985  105.228888  64.514088    6         8
# 58   78   98.888255  119.002316  78.806782    3         9
# 64   78   98.805288  120.004247  79.552284    2        10
# 70   78   98.242798  118.579859  78.010978    1        11
# ...
